# %%
import pandas as pd
airports = pd.read_csv('/Users/annettechiu/Downloads/airports.csv')
airport_freq = pd.read_csv('/Users/annettechiu/Downloads/airport-frequencies.csv')
runways = pd.read_csv('/Users/annettechiu/Downloads/runways.csv')
navaids = pd.read_csv('/Users/annettechiu/Downloads/navaids.csv')
countries = pd.read_csv('/Users/annettechiu/Downloads/countries.csv')
regions = pd.read_csv('/Users/annettechiu/Downloads/regions.csv')

# %%
import numpy as np
import math
import matplotlib.pyplot as plt

# %%
import pandas as pd # to load cities dataset
from geopy import distance # to calculate distance on the surface

# %% [markdown]
# # 從網站導入飛機資料庫 https://ourairports.com/data/
# 儲存飛機資料庫到airports = pd.read_csv('/Users/annettechiu/Downloads/airports.csv')
# 、機場飛機頻率、機場跑道

# %%
import math
# Python 3 program for the
# haversine formula
def haversine(lat1, lon1, lat2, lon2):
     
    # distance between latitudes
    # and longitudes
    dLat = (lat2 - lat1) * math.pi / 180.0
    dLon = (lon2 - lon1) * math.pi / 180.0
 
    # convert to radians
    lat1 = (lat1) * math.pi / 180.0
    lat2 = (lat2) * math.pi / 180.0
 
    # apply formulae
    a = (pow(math.sin(dLat / 2), 2) +
         pow(math.sin(dLon / 2), 2) *
             math.cos(lat1) * math.cos(lat2));
    rad = 6371
    c = 2 * math.asin(math.sqrt(a))
    return rad * c

# Driver code
if __name__ == "__main__":
    lat1 = 35.289448
    lon1 = 79.79672
    lat2 = 35.290348
    lon2 = 79.796616
     
    print(haversine(lat1, lon1,lat2, lon2), "K.M.")
# Out:
# 0.10051960641905637 K.M.

# %%
# 建立地圖與設定位置
fmap = folium.Map(location=[35.709635, 139.810851], zoom_start=100)
fmap  # 在notebook中顯示地圖
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
row_count = airports.shape[0] # 0 for row
column_count = airports.shape[1] # 1 for column
print("Number of rows:", row_count)
print("Number of columns:", column_count)
# Out:
# Number of rows: 78264
# Number of columns: 18

# %%
from geopy.distance import geodesic
distance = geodesic((39.995304, 116.308264), (40.003304, 116.326759)).km  
print("距离：{:.3f}km".format(distance))
# Out:
# 距离：1.812km

# %%
pip install geopy -i http://pypi.douban.com/simple --trusted-host pypi.douban.com
# Out:
# Looking in indexes: http://pypi.douban.com/simple
# ...
#      |████████████████████████████████| 125 kB 440 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 40 kB 23 kB/s eta 0:00:015
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
airports.head(15)
# Out:
#         id ident           type                                name  \
# 0     6523   00A       heliport                   Total RF Heliport
# 1   323361  00AA  small_airport                Aero B Ranch Airport
# 2     6524  00AK  small_airport                        Lowell Field
# 3     6525  00AL  small_airport                        Epps Airpark
# 4   506791  00AN  small_airport                Katmai Lodge Airport
# 5     6526  00AR         closed  Newport Hospital & Clinic Heliport
# 6   322127  00AS  small_airport                      Fulton Airport
# 7     6527  00AZ  small_airport                      Cordes Airport
# 8     6528  00CA  small_airport             Goldstone (GTS) Airport
# 9   324424  00CL  small_airport                 Williams Ag Airport
# 10  322658  00CN       heliport     Kitchen Creek Helibase Heliport
# 11    6529  00CO         closed                          Cass Field
# 12    6531  00FA  small_airport                 Grass Patch Airport
# ...

# %%
# to start with let's filter only 2 capitals. Rome and Paris.
ropa = airports[airports["id"].isin(["6523","6531"])].reset_index()
ropa
# Out:
#    index    id ident           type                 name  latitude_deg  \
# 0      0  6523   00A       heliport    Total RF Heliport     40.070985
# 1     12  6531  00FA  small_airport  Grass Patch Airport     28.645500
#
#    longitude_deg  elevation_ft continent iso_country iso_region municipality  \
# 0     -74.933689          11.0       NaN          US      US-PA     Bensalem
# 1     -82.219002          53.0       NaN          US      US-FL     Bushnell
#
#   scheduled_service gps_code iata_code local_code  \
# 0                no     K00A       NaN        00A
# 1                no     00FA       NaN       00FA
#
#                                            home_link wikipedia_link keywords
# 0  https://www.penndot.pa.gov/TravelInPA/airports...            NaN      NaN
# 1                                                NaN            NaN      NaN

# %%
d = distance.distance((ropa.loc[0, "latitude_deg"], ropa.loc[0, "longitude_deg"]), (ropa.loc[1, "latitude_deg"], ropa.loc[1, "longitude_deg"]))
d, d.km, d.miles
# Out:
# (Distance(1432.4069532337544), 1432.4069532337544, 890.056416299905)

# %%
results = []
for f in [distance.distance, distance.great_circle, distance.geodesic]:
    for mes in ["kilometers","km","miles","mi","nautical","nm","feet","ft"]:
        d = f((ropa.loc[0, "latitude_deg"], ropa.loc[0, "longitude_deg"]), (ropa.loc[1, "latitude_deg"], ropa.loc[1, "longitude_deg"]))
        results.append({"method": f.__name__, "measurement": mes, "value": getattr(d, mes)})

# show as dataframe
results_df = pd.DataFrame(results)
results_df.pivot_table(index="method", columns="measurement", values="value")
# Out:
# measurement           feet            ft   kilometers           km  \
# method
# geodesic      4.699498e+06  4.699498e+06  1432.406953  1432.406953
# great_circle  4.706066e+06  4.706066e+06  1434.409056  1434.409056
#
# measurement           mi       miles    nautical          nm
# method
# geodesic      890.056416  890.056416  773.437880  773.437880
# great_circle  891.300465  891.300465  774.518929  774.518929

# %%
# the distnace for various ellipsiods
for ellipsoid in distance.ELLIPSOIDS:
    for mes in ["kilometers","km","miles","mi","nautical","nm","feet","ft"]:
        d = distance.geodesic((ropa.loc[0, "latitude_deg"], ropa.loc[0, "longitude_deg"]), 
                              (ropa.loc[1, "latitude_deg"], ropa.loc[1, "longitude_deg"]), ellipsoid=ellipsoid)
        results.append({"method": f"geodesic: {ellipsoid}", "measurement": mes, "value": getattr(d, mes)})

# show as dataframe
results_df = pd.DataFrame(results)
results_df.pivot_table(index="method", columns="measurement", values="value")
# Out:
# measurement                      feet            ft   kilometers           km  \
# method
# geodesic                 4.699498e+06  4.699498e+06  1432.406953  1432.406953
# geodesic: Airy (1830)    4.699118e+06  4.699118e+06  1432.291017  1432.291017
# geodesic: Clarke (1880)  4.699387e+06  4.699387e+06  1432.373152  1432.373152
# geodesic: GRS-67         4.699515e+06  4.699515e+06  1432.412031  1432.412031
# geodesic: GRS-80         4.699498e+06  4.699498e+06  1432.406953  1432.406953
# geodesic: Intl 1924      4.699633e+06  4.699633e+06  1432.448032  1432.448032
# geodesic: WGS-84         4.699498e+06  4.699498e+06  1432.406953  1432.406953
# great_circle             4.706066e+06  4.706066e+06  1434.409056  1434.409056
#
# measurement                      mi       miles    nautical          nm
# method
# geodesic                 890.056416  890.056416  773.437880  773.437880
# geodesic: Airy (1830)    889.984377  889.984377  773.375279  773.375279
# ...

# %%
airport_freq.head(5)
# Out:
#        id  airport_ref airport_ident   type          description  \
# 0   70518         6528          00CA   CTAF                 CTAF
# 1  307581         6589          01FL  ARCAL                  NaN
# 2   75239         6589          01FL   CTAF  CEDAR KNOLL TRAFFIC
# 3   60191         6756          04CA   CTAF                 CTAF
# 4   59287         6779          04MS   UNIC               UNICOM
#
#    frequency_mhz
# 0          122.9
# 1          122.9
# 2          122.8
# 3          122.9
# 4          122.8

# %%
runways.head(5)
# Out:
#        id  airport_ref airport_ident  length_ft  width_ft surface  lighted  \
# 0  269408         6523           00A       80.0      80.0  ASPH-G        1
# 1  255155         6524          00AK     2500.0      70.0    GRVL        0
# 2  254165         6525          00AL     2300.0     200.0    TURF        0
# 3  506792       506791          00AN     4517.0      60.0     GVL        0
# 4  270932         6526          00AR       40.0      40.0   GRASS        0
#
#    closed le_ident  le_latitude_deg  le_longitude_deg  le_elevation_ft  \
# 0       0       H1              NaN               NaN              NaN
# 1       0        N              NaN               NaN              NaN
# 2       0       01              NaN               NaN              NaN
# 3       0        3              NaN               NaN              NaN
# 4       0       H1              NaN               NaN              NaN
#
#    le_heading_degT  le_displaced_threshold_ft he_ident  he_latitude_deg  \
# ...

# %%
airports[airports.ident == 'KLAX'].id
# Out:
# 37775    3632
# Name: id, dtype: int64

# %%
airports.type.unique()
# Out:
# array(['heliport', 'small_airport', 'closed', 'seaplane_base',
#        'balloonport', 'medium_airport', 'large_airport'], dtype=object)

# %%
airports[(airports.iso_region == 'US-CA') & (airports.type == 'seaplane_base')].head(3)
# Out:
#          id ident           type                                 name  \
# 1033   7436   0O0  seaplane_base     San Luis Reservoir Seaplane Base
# 2616   8877  22CA  seaplane_base       Commodore Center Seaplane Base
# 6599  12298  5CA9  seaplane_base  Konocti  - Clear Lake Seaplane Base
#
#       latitude_deg  longitude_deg  elevation_ft continent iso_country  \
# 1033     37.058300    -121.125999         544.0       NaN          US
# 2616     37.878893    -122.512697           NaN       NaN          US
# 6599     38.977699    -122.718002        1326.0       NaN          US
#
#      iso_region municipality scheduled_service gps_code iata_code local_code  \
# 1033      US-CA    Los Banos                no      0O0       NaN        0O0
# 2616      US-CA  Mill Valley                no     22CA       NaN       22CA
# 6599      US-CA  Kelseyville                no     5CA9       NaN       5CA9
#
#      home_link wikipedia_link keywords
# 1033       NaN            NaN      NaN
# ...

# %%
airports[(airports.iso_region == 'US-CA') & (airports.type == 'large_airport')][['ident', 'name', 'municipality']]
# Out:
#       ident                                             name   municipality
# 36380  KCMA                  Camarillo International Airport      Camarillo
# 37775  KLAX                Los Angeles International Airport    Los Angeles
# 38307  KOAK       Metropolitan Oakland International Airport        Oakland
# 38363  KONT                    Ontario International Airport        Ontario
# 39916  KSAN                  San Diego International Airport      San Diego
# 39956  KSFO              San Francisco International Airport  San Francisco
# 39977  KSJC  Norman Y. Mineta San Jose International Airport       San Jose
# 39999  KSMF                 Sacramento International Airport     Sacramento
# 40005  KSNA   John Wayne Orange County International Airport      Santa Ana

# %%
airport_freq[airport_freq.airport_ident == 'KLAX'].sort_values('type')
# Out:
#           id  airport_ref airport_ident  type description  frequency_mhz
# 12211  60767         3632          KLAX   APP   SOCAL APP          36.07
# 12212  60766         3632          KLAX   APP   SOCAL APP         124.30
# 12213  60768         3632          KLAX  ATIS        ATIS         133.80
# 12214  60769         3632          KLAX   CLD    CLNC DEL         121.40
# 12215  60770         3632          KLAX   DEP   SOCAL DEP         124.30
# 12216  60771         3632          KLAX   GND         GND         121.65
# 12217  60772         3632          KLAX  MISC          CG          34.50
# 12218  60773         3632          KLAX  MISC          CG         898.40
# 12219  60774         3632          KLAX   OPS          AF          37.22
# 12220  60775         3632          KLAX   TWR         TWR         119.80
# 12221  60776         3632          KLAX  UNIC      UNICOM         122.95

# %%
airport_freq[airport_freq.airport_ident == 'KLAX'].sort_values('type', ascending=False)
# Out:
#           id  airport_ref airport_ident  type description  frequency_mhz
# 12221  60776         3632          KLAX  UNIC      UNICOM         122.95
# 12220  60775         3632          KLAX   TWR         TWR         119.80
# 12219  60774         3632          KLAX   OPS          AF          37.22
# 12217  60772         3632          KLAX  MISC          CG          34.50
# 12218  60773         3632          KLAX  MISC          CG         898.40
# 12216  60771         3632          KLAX   GND         GND         121.65
# 12215  60770         3632          KLAX   DEP   SOCAL DEP         124.30
# 12214  60769         3632          KLAX   CLD    CLNC DEL         121.40
# 12213  60768         3632          KLAX  ATIS        ATIS         133.80
# 12211  60767         3632          KLAX   APP   SOCAL APP          36.07
# 12212  60766         3632          KLAX   APP   SOCAL APP         124.30

# %%
airports[airports.type.isin(['heliport', 'balloonport'])]
# Out:
#            id    ident      type                             name  \
# 0        6523      00A  heliport                Total RF Heliport
# 10     322658     00CN  heliport  Kitchen Creek Helibase Heliport
# 16       6535     00GE  heliport                 Caffrey Heliport
# 17       6536     00HI  heliport               Kaupulehu Heliport
# 22       6540     00IN  heliport  St Mary Medical Center Heliport
# ...       ...      ...       ...                              ...
# 78201  351677  ZW-0055  heliport          Elephant Hills Heliport
# 78202  351678  ZW-0056  heliport             Chikopokopo Heliport
# 78203  351679  ZW-0057  heliport                  Masuwe Heliport
# 78205  351689  ZW-0059  heliport                Big Four Heliport
# 78259   46378  ZZ-0001  heliport                  Sealand Helipad
#
#        latitude_deg  longitude_deg  elevation_ft continent iso_country  \
# 0         40.070985     -74.933689          11.0       NaN          US
# ...

# %%
airports[~airports.type.isin(['heliport', 'balloonport'])]
# Out:
#            id    ident            type                                name  \
# 1      323361     00AA   small_airport                Aero B Ranch Airport
# 2        6524     00AK   small_airport                        Lowell Field
# 3        6525     00AL   small_airport                        Epps Airpark
# 4      506791     00AN   small_airport                Katmai Lodge Airport
# 5        6526     00AR          closed  Newport Hospital & Clinic Heliport
# ...       ...      ...             ...                                 ...
# 78258   32753     ZYYY  medium_airport             Shenyang Dongta Airport
# 78260  307326  ZZ-0002   small_airport           Glorioso Islands Airstrip
# 78261  346788  ZZ-0003   small_airport               Fainting Goat Airport
# 78262  342102     ZZZW          closed              Scandium City Heliport
# 78263  313629     ZZZZ   small_airport              Satsuma Iōjima Airport
#
# ...

# %%
airports.groupby(['iso_country', 'type']).size()
# Out:
# iso_country  type
# AD           closed              1
#              heliport            2
# AE           closed              4
#              heliport          203
#              large_airport       4
#                               ...
# ZW           closed              6
#              heliport            5
#              large_airport       1
#              medium_airport      8
#              small_airport     135
# Length: 988, dtype: int64

# %%
airports.groupby(['iso_country', 'type']).size().to_frame('size').reset_index().sort_values(['iso_country', 'size'], ascending=[True, False])
# Out:
#     iso_country            type  size
# 1            AD        heliport     2
# 0            AD          closed     1
# 3            AE        heliport   203
# 7            AE   small_airport    29
# 5            AE  medium_airport     9
# ..          ...             ...   ...
# 987          ZW   small_airport   135
# 986          ZW  medium_airport     8
# 983          ZW          closed     6
# 984          ZW        heliport     5
# 985          ZW   large_airport     1
#
# [988 rows x 3 columns]

# %%
airports.groupby(['iso_country', 'type']).size()
# Out:
# iso_country  type
# AD           closed              1
#              heliport            2
# AE           closed              4
#              heliport          203
#              large_airport       4
#                               ...
# ZW           closed              6
#              heliport            5
#              large_airport       1
#              medium_airport      8
#              small_airport     135
# Length: 988, dtype: int64

# %%
airports.groupby(['iso_country', 'type']).size().to_frame('size').reset_index().sort_values(['iso_country', 'size'], ascending=[True, False])
# Out:
#     iso_country            type  size
# 1            AD        heliport     2
# 0            AD          closed     1
# 3            AE        heliport   203
# 7            AE   small_airport    29
# 5            AE  medium_airport     9
# ..          ...             ...   ...
# 987          ZW   small_airport   135
# 986          ZW  medium_airport     8
# 983          ZW          closed     6
# 984          ZW        heliport     5
# 985          ZW   large_airport     1
#
# [988 rows x 3 columns]

# %%
airports[airports.iso_country == 'US'].groupby('type').filter(lambda g: len(g) > 1000).groupby('type').size().sort_values(ascending=False)
# Out:
# type
# small_airport    15000
# heliport          7914
# closed            6470
# dtype: int64

# %%
runways.agg({'length_ft': ['min', 'max', 'mean', 'median']})
# Out:
#            length_ft
# min         0.000000
# max     30000.000000
# mean     3238.656964
# median   2700.000000

# %%
airport_freq.merge(airports[airports.ident == 'KLAX'][['id']], left_on='airport_ref', right_on='id', how='inner')[['airport_ident', 'type', 'description', 'frequency_mhz']]
# Out:
#    airport_ident  type description  frequency_mhz
# 0           KLAX   APP   SOCAL APP          36.07
# 1           KLAX   APP   SOCAL APP         124.30
# 2           KLAX  ATIS        ATIS         133.80
# 3           KLAX   CLD    CLNC DEL         121.40
# 4           KLAX   DEP   SOCAL DEP         124.30
# 5           KLAX   GND         GND         121.65
# 6           KLAX  MISC          CG          34.50
# 7           KLAX  MISC          CG         898.40
# 8           KLAX   OPS          AF          37.22
# 9           KLAX   TWR         TWR         119.80
# 10          KLAX  UNIC      UNICOM         122.95

# %%
pd.concat([airports[airports.ident == 'KLAX'][['name', 'municipality']], airports[airports.ident == 'KLGB'][['name', 'municipality']]])
# Out:
#                                        name municipality
# 37775     Los Angeles International Airport  Los Angeles
# 37801  Long Beach Airport (Daugherty Field)   Long Beach

# %%
df1 = pd.DataFrame({'id': [1, 2], 'name': ['Harry Potter', 'Ron Weasley']})

# %%
df2 = pd.DataFrame({'id': [3], 'name': ['Hermione Granger']})

# %%
pd.concat([df1, df2]).reset_index(drop=True)
# Out:
#    id              name
# 0   1      Harry Potter
# 1   2       Ron Weasley
# 2   3  Hermione Granger

# %%
airports.loc[airports['ident'] == 'KLAX', 'home_link'] = 'http://www.lawa.org/welcomelax.aspx'

# %%
airports.loc[airports['ident'] == 'KLAX', 'home_link'] = 'http://www.lawa.org/welcomelax.aspx'

# %%
regions.head(5)
# Out:
#        id   code local_code                        name continent iso_country  \
# 0  302811  AD-02         02              Canillo Parish        EU          AD
# 1  302812  AD-03         03               Encamp Parish        EU          AD
# 2  302813  AD-04         04           La Massana Parish        EU          AD
# 3  302814  AD-05         05               Ordino Parish        EU          AD
# 4  302815  AD-06         06  Sant Julià de Lòria Parish        EU          AD
#
#                                       wikipedia_link  \
# 0              https://en.wikipedia.org/wiki/Canillo
# 1               https://en.wikipedia.org/wiki/Encamp
# 2           https://en.wikipedia.org/wiki/La_Massana
# 3               https://en.wikipedia.org/wiki/Ordino
# 4  https://en.wikipedia.org/wiki/Sant_Julià_de_Lòria
#
#                                  keywords
# 0              Airports in Canillo Parish
# 1               Airports in Encamp Parish
# 2           Airports in La Massana Parish
# ...

# %%
countries.head(5)
# Out:
#        id code                  name continent  \
# 0  302672   AD               Andorra        EU
# 1  302618   AE  United Arab Emirates        AS
# 2  302619   AF           Afghanistan        AS
# 3  302722   AG   Antigua and Barbuda       NaN
# 4  302723   AI              Anguilla       NaN
#
#                                       wikipedia_link  \
# 0              https://en.wikipedia.org/wiki/Andorra
# 1  https://en.wikipedia.org/wiki/United_Arab_Emir...
# 2          https://en.wikipedia.org/wiki/Afghanistan
# 3  https://en.wikipedia.org/wiki/Antigua_and_Barbuda
# 4             https://en.wikipedia.org/wiki/Anguilla
#
#                                  keywords
# 0                       Andorran airports
# 1  UAE,مطارات في الإمارات العربية المتحدة
# 2                                     NaN
# 3                       Antiguan airports
# 4                                     NaN

# %%
fmap = folium.Map(location=[35.709635, 139.810851], zoom_start=16)
fmap  # 在notebook中顯示地圖
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...
